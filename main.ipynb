# %%
from household import Household
from village import Village
from agent import Agent
from agent import Vec1
import pandas as pd
import utils
vec1 = pd.read_csv('demog_vectors.csv')

# agents = [Agent(age=30, gender='F', calories_needed=2000, proteins_needed=50, water_needed=2, household_id=1, vec1=vec1)]
# households = [
#     Household(id=1, members=agents, location='Original Location', food_storage=100, luxury_good_storage=10, land_quality='good')
# ]
# village = Village(households=households, network=None, land_types=['good', 'average', 'poor'])
# village.run_simulation_step()
vec1_instance = Vec1()
village = utils.generate_random_village(10, vec1_instance)
for _ in range(10):  # Example: run for 10 steps
    village.run_simulation_step()
village.plot_simulation_results()
# Out:
# Simulation Step 1
# Household 0 produced 138.00 units of food.
# Household 0 consumed 20.46 units of food.
# Household 0 traded 3 units of luxury goods.
# Household 0 migrated to New Location 81.
# Household 1 produced 33.50 units of food.
# Household 1 consumed 66.75 units of food.
# Household 1 traded 3 units of luxury goods.
# Household 1 migrated to New Location 67.
# Household 2 produced 126.00 units of food.
# Household 2 consumed 66.30 units of food.
# Household 2 traded 9 units of luxury goods.
# Household 2 migrated to New Location 79.
# Household 3 produced 30.00 units of food.
# Household 3 consumed 24.74 units of food.
# Household 3 traded 2 units of luxury goods.
# Household 3 migrated to New Location 11.
# Household 4 produced 67.00 units of food.
# Household 4 consumed 120.27 units of food.
# Household 4 traded 1 units of luxury goods.
# Household 4 migrated to New Location 49.
# Household 5 produced 100.50 units of food.
# Household 5 consumed 89.79 units of food.
# ...
